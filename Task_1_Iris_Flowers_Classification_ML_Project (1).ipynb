# %% [markdown]
# # Introduction

# %% [markdown]
# This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.
#
# Data set link: http://archive.ics.uci.edu/ml/datasets/Iris

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So, we have given a data set which have following attributes:
# 1. sepal length in cm
# 2. sepal width in cm
# 3. petal length in cm
# 4. petal width in cm
# 5. class:
# -- Iris Setosa
# -- Iris Versicolour
# -- Iris Virginica
#
# **The aim of the iris flower classification is to classify the models based on their specific features.**

# %% [markdown]
# # Import modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Load Dataset

# %%
from google.colab import files
d=files.upload()
# Out:
#      <input type="file" id="files-43aa913e-fedc-4ace-815f-fffee80257fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43aa913e-fedc-4ace-815f-fffee80257fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.data to iris (1).data

# %%
columns = ['Sepal_length', 'Sepal_width', 'Petal_length', 'Petal_width', 'Species'] 
df = pd.read_csv('iris.data', names=columns)
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Analyze the Dataset

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull().sum()   #to check null values

# %% [markdown]
# We can observe there is no null value in the data set. So, no requirement to replace or drop any row or column.

# %%
df.describe()
# Out:
#        Sepal_length  Sepal_width  Petal_length  Petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['Species'].value_counts()   #to check value count per species
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# We can observe there is each 50 counts of Iris-setosa, Iris-versicolor and Iris-virginica.

# %% [markdown]
# # Visualize the Dataset

# %% [markdown]
# To visualize the whole dataset here we are using seaborn module which we have already imported.

# %%
sns.pairplot(df, hue='Species');

# %% [markdown]
# From above visualization, we can observe that Iris-setosa(Blue) is well separated from the other two flowers and we can easily differentiate among all classes of Iris by their 'Petal length' and 'Petal width' as we can see in the graph above.

# %%
sns.scatterplot(x=df['Petal_length'], y=df['Petal_width'], hue=df['Species'], s=100);

# %% [markdown]
# We can now differentiate in the Sepal Width of all classes

# %%
setosa_df = df[df.Species == 'Iris-setosa']
versicolor_df = df[df.Species == 'Iris-versicolor']
virginica_df = df[df.Species == 'Iris-virginica']

plt.title('Distribution of Sepal Width')
plt.hist([setosa_df['Sepal_width'],versicolor_df['Sepal_width'], virginica_df['Sepal_width']],bins=np.arange(2, 5, 0.25), stacked=True);
plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %%
data = df.values
X = data[:,0:4]
Y = data[:,4]
print(X)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.0 3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.0 1.4 0.1]
#  [4.3 3.0 1.1 0.1]
#  [5.8 4.0 1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.0 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.0 3.0 1.6 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.0 3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.0 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.0 3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
Y_Data = np.array([np.average(X[:, i][Y==j].astype('float32'))
                     for i in range (X.shape[1])             #here X.shape[1]=4
                          for j in (np.unique(Y))])               #np.unique(Y) = three classes in single row
Y_Data_reshaped = Y_Data.reshape(4, 3)
Y_Data_reshaped = np.swapaxes(Y_Data_reshaped, 0, 1)
X_axis = np.arange(len(columns)-1)
print(X_axis)
print(Y_Data_reshaped)
print(Y_Data_reshaped[0])
# Out:
# [0 1 2 3]
# [[5.006     3.418     1.4640001 0.244    ]
#  [5.9360003 2.7700002 4.26      1.3260001]
#  [6.5880003 2.974     5.552     2.026    ]]
# [5.006     3.418     1.4640001 0.244    ]

# %%
width=0.3
plt.bar(X_axis, Y_Data_reshaped[0], width, label = 'Setosa')
plt.bar(X_axis+width, Y_Data_reshaped[1], width, label = 'Versicolour')
plt.bar(X_axis+width*2, Y_Data_reshaped[2], width, label = 'Virginica')
plt.xticks(X_axis, columns[:4])
plt.xlabel("Features")
plt.ylabel("Value in cm.")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# We concluded that Setosa have the Widest Sepal width and the narrowest Petal
# width.
#
# The petal width of Setosa is even more narrower than its sepal width.

# %% [markdown]
# # Split and Train the Dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)
print(y_test)
# Out:
# ['Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-setosa' 'Iris-setosa' 'Iris-virginica'
#  'Iris-setosa' 'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-setosa'
#  'Iris-virginica' 'Iris-setosa' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-setosa' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor']

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# **MODEL1**:Support vector machine algorithm

# %%
from sklearn.svm import SVC

model_svc = SVC()
model_svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
prediction1 = model_svc.predict(x_test)
#calculate the accuracy
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediction1)*100)
for i in range(len(prediction1)):
  print(y_test[i],prediction1[i])
# Out:
# 96.66666666666667
# Iris-virginica Iris-virginica
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-virginica
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-virginica Iris-virginica
# Iris-versicolor Iris-versicolor

# %% [markdown]
# **Model2**:Logisitic Regression

# %%
#Logisitic Regression
from sklearn.linear_model import LogisticRegression

model_LR = LogisticRegression()
model_LR.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
prediction2 = model_LR.predict(x_test)
#calculate the accuracy
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediction2)*100)
for i in range(len(prediction1)):
  print(y_test[i],prediction1[i])
# Out:
# 96.66666666666667
# Iris-virginica Iris-virginica
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-virginica
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-virginica Iris-virginica
# Iris-versicolor Iris-versicolor

# %% [markdown]
# **Model3**:Decision TreeClassifier

# %%
#DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

model_DTC = DecisionTreeClassifier()
model_DTC.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction3 = model_svc.predict(x_test)
#calculate the accuracy
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediction3)*100)
# Out:
# 96.66666666666667

# %%
# A detailed classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction2))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.91      0.95        11
#  Iris-virginica       0.89      1.00      0.94         8
#
#        accuracy                           0.97        30
#       macro avg       0.96      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
X_new = np.array([[3,2,1,0.2],[ 4.9, 2.2, 3.8, 1.1 ], [ 5.3, 2.5, 4.6, 1.9]])
#Prediction of the species from the input vector
Prediction  = model_svc.predict(X_new)
print("Prediction of  species: {}".format(Prediction))
# Out:
# Prediction of  species: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
